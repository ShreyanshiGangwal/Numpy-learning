# %% [markdown]
# # Mini Projects Based on Numpy

# %%
import numpy as np

# %% [markdown]
#  ---------------------------------------------------
# ## 1. Student Result Analyzer

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###

# %% [markdown]
#  ---------------------------------------------------
# ###
